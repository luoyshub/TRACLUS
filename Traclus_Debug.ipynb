# %%
# %load_ext autoreload
# %autoreload 2

# %%
import src.traclus.traclus as tr
from matplotlib import pyplot as plt
import numpy as np
import pickle

# %% [markdown]
# ### Testing the point projection function

# %%
line = np.array([[0,0], [1,0.75]])
point = np.array([0.5, 0.9])

# Plot line and point
plt.plot(line[:,0], line[:,1], 'b')
plt.plot(point[0], point[1], 'ro')

# %%
# Get point projection
proj = tr.get_point_projection_on_line(point, line)

# Plot the line, point, and point projection
plt.plot(line[:,0], line[:,1], 'b')
plt.plot(point[0], point[1], 'ro')
plt.plot(proj[0], proj[1], 'go')

# Plot a line from the projection to the point
plt.plot([proj[0], point[0]], [proj[1], point[1]], 'g')

print(proj)
# Out:
# [0.752 0.564]

# %%
# The Case of a Vertical Line
line = np.array([[0,0], [0,1]])
point = np.array([0.5, 0.9])

# Plot line and point
plt.plot(line[:,0], line[:,1], 'b')
plt.plot(point[0], point[1], 'ro')

# %%
# Get the projection then plot
proj = tr.get_point_projection_on_line(point, line)
plt.plot(line[:,0], line[:,1], 'b')
plt.plot(point[0], point[1], 'ro')
plt.plot(proj[0], proj[1], 'go')
plt.plot([proj[0], point[0]], [proj[1], point[1]], 'g')

# %%
# The Case that the Point is on the Line
line = np.array([[0,0], [1,1]])
point = np.array([0.5, 0.5])

# Get projection then plot
proj = tr.get_point_projection_on_line(point, line)
plt.plot(line[:,0], line[:,1], 'b')
plt.plot(point[0], point[1], 'ro')
plt.plot(proj[0], proj[1], 'go')
plt.plot([proj[0], point[0]], [proj[1], point[1]], 'g')

# %%
# The Case that the point is below the line
line = np.array([[0,0], [1,1]])
point = np.array([0.7, -0.5])

# Get projection then plot
proj = tr.get_point_projection_on_line(point, line)
plt.plot(line[:,0], line[:,1], 'b')
plt.plot(point[0], point[1], 'ro')
plt.plot(proj[0], proj[1], 'go')
plt.plot([proj[0], point[0]], [proj[1], point[1]], 'g')

print(proj)
# Out:
# [0.1 0.1]

# %%
# The case that the point has no projection
line = np.array([[0,0], [1,1]])
point = np.array([1.5, 0.9])

# Get projection then plot
proj = tr.get_point_projection_on_line(point, line)
plt.plot(line[:,0], line[:,1], 'b')
plt.plot(point[0], point[1], 'ro')
plt.plot(proj[0], proj[1], 'go')
plt.plot([proj[0], point[0]], [proj[1], point[1]], 'g')

# %%
# The case that the light has a really light slope
line = np.array([[0,0], [1,0.0001]])
point = np.array([0.5, 0.9])

# Get projection then plot
proj = tr.get_point_projection_on_line(point, line)
plt.plot(line[:,0], line[:,1], 'b')
plt.plot(point[0], point[1], 'ro')
plt.plot(proj[0], proj[1], 'go')
plt.plot([proj[0], point[0]], [proj[1], point[1]], 'g')

# %%
# The case that the line is horizontal
line = np.array([[0,0], [1,0]])
point = np.array([0.5, 0.9])

# Get projection then plot
proj = tr.get_point_projection_on_line(point, line)
plt.plot(line[:,0], line[:,1], 'b')
plt.plot(point[0], point[1], 'ro')
plt.plot(proj[0], proj[1], 'go')
plt.plot([proj[0], point[0]], [proj[1], point[1]], 'g')

# %%
# The case that the line has an extreme slope
line = np.array([[0,0], [0.1,1]])
point = np.array([0.2, 0.9])

# Get projection then plot
proj = tr.get_point_projection_on_line(point, line)
plt.plot(line[:,0], line[:,1], 'b')
plt.plot(point[0], point[1], 'ro')
plt.plot(proj[0], proj[1], 'go')
plt.plot([proj[0], point[0]], [proj[1], point[1]], 'g')

# %%
# The case that the point is near the line's left point
line = np.array([[0,0], [1,1]])
point = np.array([0.0001, 0.0001])

# Get projection then plot
proj = tr.get_point_projection_on_line(point, line)
plt.plot(line[:,0], line[:,1], 'b')
plt.plot(point[0], point[1], 'ro')
plt.plot(proj[0], proj[1], 'go')
plt.plot([proj[0], point[0]], [proj[1], point[1]], 'g')

# %% [markdown]
# ### Testing the `d_euclidean` function

# %%
# Get the Euclidean distance between two random points
p1 = np.random.rand(2)
p2 = np.random.rand(2)

# Plot the points and print the Euclidean distanace
plt.plot(p1[0], p1[1], 'ro')
plt.plot(p2[0], p2[1], 'bo')

print(tr.d_euclidean(p1,p2))
# Out:
# 1.0359605581723588

# %%
# The case that the points are the same
p1 = np.array([0.5, 0.5])
p2 = np.array([0.5, 0.5])

# Plot the points and print the Euclidean distance
plt.plot(p1[0], p1[1], 'ro')
plt.plot(p2[0], p2[1], 'bo')

print(tr.d_euclidean(p1,p2))
# Out:
# 0.0

# %% [markdown]
# ### Testing the `d_perpendicular` function

# %%
# Get the perpendicular distance between two nearly parallel lines
line1 = np.array([[0,0], [1,1]])
line2 = np.array([[0.1,1.25], [0.5,2]])

# Plot the two lines
plt.plot(line1[:,0], line1[:,1], 'b')
plt.plot(line2[:,0], line2[:,1], 'r')

# Get the perpendicular distance
d = tr.d_perpendicular(line1, line2)
print(d)

# # Plot ps and pe
# plt.plot(ps[0], ps[1], 'go')
# plt.plot(pe[0], pe[1], 'go')

# # Plot p1 and p2
# plt.plot(p1[0], p1[1], 'ro')
# plt.plot(p2[0], p2[1], 'ro')
# Out:
# 0.9532599908637512

# %% [markdown]
# ### Testing the `d_parallel` function

# %% [markdown]
# ### Testing the `d_angular` function

# %%
# Get the angular distance between 2 lines
line1 = np.array([[0,0], [1,0]])
line2 = np.array([[0,0], [1,0.5]])

# Plot the two lines
plt.plot(line1[:,0], line1[:,1], 'b')
plt.plot(line2[:,0], line2[:,1], 'r')

# Get the angular distance
d = tr.d_angular(line1, line2)
print(d * 180 / np.pi)
# Out:
# 28.64788975654116

# %% [markdown]
# ### Testing the `partition` function

# %%
test_line = np.array([[2, 0.8], [1.5, 0.9], [0, 0.75], [-0.5, 0.5], [0, 0.2], [0.5, 0.1], [1, 0.2], [1.5, 0.25], [2, 0.2]])
partitions = tr.partition(test_line)

print("Input Line:")
print(test_line)
print("Actual Output:")
print(partitions)

# Plot the test line
plt.plot(test_line[:,0], test_line[:,1], 'b')

# Plot the partitions as a line
plt.plot(partitions[:,0], partitions[:,1], 'r')
# Out:
# Input Line:
# [[ 2.    0.8 ]
#  [ 1.5   0.9 ]
#  [ 0.    0.75]
#  [-0.5   0.5 ]
#  [ 0.    0.2 ]
#  [ 0.5   0.1 ]
#  [ 1.    0.2 ]
#  [ 1.5   0.25]
#  [ 2.    0.2 ]]
# Actual Output:
# [[ 2.   0.8]
#  [-0.5  0.5]
#  [ 1.   0.2]
#  [ 2.   0.2]]

# %% [markdown]
# ### Testing the `generate_representative_trajectory` function

# %%
vehicle_detections = None
with open("../../local_checkpoint_files/yt.vts", "rb") as f:
    vehicle_detections = pickle.load(f)

# Get the center of the bounding box
all_trajectories = []
for i in range(len(vehicle_detections)):
    vehicle_detections[i]["centroids"] = np.array([[(x[0] + x[2]) / 2, (x[1] + x[3]) / 2] for x in vehicle_detections[i]["centroids"]])
    all_trajectories.append(tr.sub_sample_trajectory(vehicle_detections[i]["centroids"], sample_n=10))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-d45975eadd52> in <module>
#       1 vehicle_detections = None
# ----> 2 with open("../../local_checkpoint_files/yt.vts", "rb") as f:
#       3     vehicle_detections = pickle.load(f)
#       4
#       5 # Get the center of the bounding box
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../local_checkpoint_files/yt.vts'

# %%
# Apply TRACLUS
out = tr.traclus(all_trajectories, min_samples=5, progress_bar=True)
# Out:
# Partitioning trajectories...
# Trajectory 259/259
# Converting partitioned trajectories to segments...
# Progress: 54/606gress: 1/606
# /Users/adrielamoguis/THESIS/RLSFD/trajectory-based/traclus/traclus.py:253: RuntimeWarning: divide by zero encountered in log2
#   LH += np.log2(d_euclidean(trajectory[i], trajectory[i+1]))
# Grouping partitions...
#
# Getting representative trajectories...

# %%
# Plot the clusters
colors = ['k', 'g', 'r', 'c', 'm', 'y', 'b', 'orange']
clusters = out[3]
representative_trajectories = out[5]

for i in range(len(clusters)):
    for j in range(len(clusters[i])):
        plt.plot(clusters[i][j][:,0], clusters[i][j][:,1], color=colors[i%len(colors)])

# Plot the representative trajectories
for i in range(len(representative_trajectories)):
    plt.plot(representative_trajectories[i][:,0], representative_trajectories[i][:,1], color=colors[i%len(colors)], linewidth=2)

# %%
# Grab one cluster and plot it
cluster = clusters[4]
for i in range(len(cluster)):
    plt.plot(cluster[i][:,0], cluster[i][:,1], color=colors[2])

# %%
# Generate a representative trajectory
start_end = tr.get_representative_trajectory(cluster)
start_end
# Out:
# array([[0.37037065, 0.45229014],
#        [0.37009607, 0.45674396],
#        [0.36917907, 0.46303729],
#        [0.36779312, 0.4675347 ],
#        [0.36741107, 0.46916345],
#        [0.36823227, 0.4699352 ],
#        [0.36751075, 0.47062652],
#        [0.36645078, 0.47305955],
#        [0.36731226, 0.47687916],
#        [0.36753333, 0.47979838],
#        [0.36806046, 0.481319  ],
#        [0.36644823, 0.48217171],
#        [0.36591857, 0.48475935],
#        [0.36537141, 0.48611573],
#        [0.3649872 , 0.48793639],
#        [0.36370342, 0.48881555],
#        [0.36328633, 0.48902739],
#        [0.36272011, 0.48953966],
#        [0.3630332 , 0.49087235],
#        [0.3635178 , 0.49110657],
#        [0.36368753, 0.49357857],
#        [0.36464547, 0.49626095],
#        [0.36384586, 0.49658259],
#        [0.36779617, 0.51076039],
#        [0.36957276, 0.519992  ],
#        [0.36920463, 0.52109806],
#        [0.36892737, 0.52424285],
#        [0.36957642, 0.52774665],
# ...
